# %%
#Write a Python program for Handling Missing Value. Replace missing value of salary, 
#age column with mean of that column.(Use Data.csv file)
import pandas as pd
file=pd.read_csv('E:/User_Data.csv')
file

#replace missing value with their mean
#salery
#file['salery']=file[salery].fillno(file['salery'].mean())

#age
#file[age]=file[age].fileno(file[age].mean)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#) Write a Python program to generate a line plot of name Vs salary
import matplotlib.pyplot as mt
file.plot(x='User ID',y='EstimatedSalary')
mt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Download the heights and weights dataset and load the dataset froma given csv file into a 
#dataframe. Print the first, last 10 rows and random 20 rows also display shape of the 
#dataset.
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("E:/weight-height.csv")
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
#Q.2 C) Download the heights and weights dataset and load the dataset froma given csv file into a 
#dataframe. Print the first, last 10 rows and random 20 rows also display shape of the 
#dataset.
import pandas as pd
data=pd.read_csv("E:/weight-height.csv")
data.head(10)
data.tail(10)
data.sample(20)
#data.shape
# Out:
#       Gender     Height      Weight
# 7313  Female  61.190716  124.463273
# 8490  Female  66.227792  156.166353
# 3716    Male  70.284056  183.789893
# 7360  Female  67.031156  154.484357
# 3973    Male  69.696567  181.206640
# 5789  Female  65.341041  148.721400
# 1351    Male  66.928807  169.103562
# 1587    Male  68.248443  183.454229
# 4135    Male  75.076076  229.233671
# 1544    Male  73.459184  211.789008
# 2825    Male  67.231261  178.073055
# 5448  Female  65.978577  141.113931
# 1585    Male  72.281928  205.927099
# 7725  Female  63.897420  138.190283
# 4715    Male  71.775023  189.639306
# 1563    Male  71.690869  188.656335
# 175     Male  66.656164  168.014030
# 5878  Female  59.264412  117.535232
# 9091  Female  65.129191  156.901637
# 9806  Female  62.433723  131.506452

# %%
import pandas as ps
data=pd.read_csv("E://weight-height.csv")
#data
#first
#data.head(10)
#data.tail(10)
#data.sample(10)
data.shape
# Out:
# (10000, 3)
