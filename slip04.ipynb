# %%
#Generate a random array of 50 integers and display them using a line chart, scatter 
#plot, histogram and box plot. Apply appropriate color, labels and styling options.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import random
x=np.random.rand(50)
y=np.random.rand(50)
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e08443e970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e08443ef10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e08443e6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e08444d4f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e08444d7c0>],
#  'means': []}

# %%
plt.hist(x)
# Out:
# (array([6., 4., 1., 5., 7., 8., 5., 6., 2., 6.]),
#  array([0.00738378, 0.10135447, 0.19532517, 0.28929586, 0.38326656,
#         0.47723725, 0.57120794, 0.66517864, 0.75914933, 0.85312002,
#         0.94709072]),
#  <BarContainer object of 10 artists>)

# %%
#) Write a Python program to print the shape, number of rows-columns, data types, 
#feature names and the description of the data(Use User_Data.csv)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("E:/User_Data.csv")
#data
#data.shape
#data.columns
#data.dtypes
#data.describe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              392 non-null    float64
#  3   EstimatedSalary  389 non-null    float64
#  4   Purchased        400 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.8+ KB
